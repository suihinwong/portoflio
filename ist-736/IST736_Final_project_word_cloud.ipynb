# %% [markdown]
# ## Input

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Morga\programsMG\TextMining\Tweets.csv')

# %%
# Dropping the row
df.drop([314], inplace = True)

# %%
# splitting the data

y=df['sentiment'].values
X=df['text'].values

# %%
#collecting all positive labeled tweets
positive_df = df.loc[df['sentiment'] == 'positive']
# print(positive_df)

# %%
#collecting all negative labeled tweets
negative_df = df.loc[df['sentiment'] == 'negative']
# print(negative_df)

# %%
# placing all positive and negative tweets into a string
positiveText = ' '.join(positive_df["text"])
negativeText = ' '.join(negative_df["text"])
allText      = ' '.join(df["text"])

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS
from PIL import Image
import numpy as np
from wordcloud import ImageColorGenerator

# %%
#creating a word cloud in the shape of a green twitter bird
mask = np.array(Image.open(r'C:\Users\Morga\programsMG\TextMining\TwitterGreen.png'))
mask_colors = ImageColorGenerator(mask)
wc = WordCloud(stopwords=STOPWORDS,
               mask=mask, background_color="white",
               max_words=2000, max_font_size=256,
               random_state=42, width=mask.shape[1],
               height=mask.shape[0], color_func=mask_colors)
cloud = wc.generate(positiveText)
plt.title('Wordcloud of Positive Tweets')
# plt.savefig('WordcloudPositiveTweets.png')
cloud.to_file('WordcloudPositiveTweets.png')
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
#creating a word cloud in the shape of a red twitter bird
mask = np.array(Image.open(r'C:\Users\Morga\programsMG\TextMining\TwitterRed.png'))
mask_colors = ImageColorGenerator(mask)
wc = WordCloud(stopwords=STOPWORDS,
               mask=mask, background_color="white",
               max_words=2000, max_font_size=256,
               random_state=42, width=mask.shape[1],
               height=mask.shape[0], color_func=mask_colors)
cloud = wc.generate(negativeText)
plt.title('Wordcloud of Negative Tweets')
# plt.savefig('WordcloudNegativeTweets.png')
cloud.to_file('WordcloudNegativeTweets.png')
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
#creating a word cloud in the shape of a blue twitter bird
mask = np.array(Image.open(r'C:\Users\Morga\programsMG\TextMining\TwitterBlue.png'))
mask_colors = ImageColorGenerator(mask)
wc = WordCloud(stopwords=STOPWORDS,
               mask=mask, background_color="white",
               max_words=2000, max_font_size=256,
               random_state=42, width=mask.shape[1],
               height=mask.shape[0], color_func=mask_colors)
cloud = wc.generate(allText)
plt.title('Wordcloud of All Tweets')
# plt.savefig('WordcloudAllTweets.png')
cloud.to_file('WordcloudAllTweets.png')
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
